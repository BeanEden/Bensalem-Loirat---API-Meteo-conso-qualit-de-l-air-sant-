# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pymongo import MongoClient
import datetime

# %%
current_dir = os.getcwd()
end_path = current_dir + "\end_data"
end_file = end_path +'\end_data.csv'
print(end_file)

conso_path = current_dir +'\data_collection\data_transformed\Api_energie_Transforme.csv'
# Out:
# C:\Users\JC\Documents\Sup de vinci\Entrepots de donnees\Projet API\Bensalem-Loirat---API-Meteo-conso-qualit-de-l-air-sant-\end_data\end_data.csv

# %%
mongodb_url = "mongodb+srv://bean3den:faRpFh6VyRLeEf6A@cluster0.wva85.mongodb.net/"
meteo_api_url = os.getenv("API_URL_METEO_2")
meteo_api_key = os.getenv("METEO_API_KEY")

# %%
# Configurer MongoDB
client = MongoClient(mongodb_url)
db = client['API_Project']  # Nom de la base de données
collection_meteo = db['Meteo']  # Nom de la collection
collection_conso= db['Consommation_energetique']

# %%
# Récupérer les données depuis MongoDB
df_meteo = pd.DataFrame(list(collection_meteo.find()))

# %%
df_conso = pd.read_csv(conso_path, header=0)

# %%
df_conso['Date - Heure'] = pd.to_datetime(df_conso['Date - Heure'])

# %%
df_meteo = df_meteo.rename(columns={"dh_utc":"Date - Heure"})

# %%
df_conso.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99840 entries, 0 to 99839
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   _id                  99840 non-null  object
#  1   ﻿Code INSEE région   99840 non-null  int64
#  2   Région               99840 non-null  object
#  3   Nature               99840 non-null  object
#  4   Date                 99840 non-null  object
#  5   Heure                99840 non-null  object
#  6   Date - Heure         99840 non-null  datetime64[ns]
#  7   Consommation (MW)    99796 non-null  float64
#  8   Thermique (MW)       99796 non-null  float64
#  9   Nucléaire (MW)       99796 non-null  float64
#  10  Eolien (MW)          99796 non-null  float64
#  11  Solaire (MW)         99796 non-null  float64
#  12  Hydraulique (MW)     99796 non-null  float64
#  13  Pompage (MW)         99796 non-null  float64
#  14  Bioénergies (MW)     99796 non-null  float64
#  15  Ech. physiques (MW)  99796 non-null  float64
#  16  Stockage batterie    90388 non-null  float64
#  17  Déstockage batterie  90388 non-null  float64
#  18  TCO Thermique (%)    99674 non-null  float64
#  19  TCH Thermique (%)    99796 non-null  float64
#  20  TCO Nucléaire (%)    99674 non-null  float64
#  21  TCH Nucléaire (%)    0 non-null      float64
#  22  TCO Eolien (%)       99674 non-null  float64
#  23  TCH Eolien (%)       99796 non-null  float64
#  24  TCO Solaire (%)      99674 non-null  float64
#  25  TCH Solaire (%)      99796 non-null  float64
#  26  TCO Hydraulique (%)  99674 non-null  float64
#  27  TCH Hydraulique (%)  99796 non-null  float64
#  28  TCO Bioénergies (%)  99674 non-null  float64
#  29  TCH Bioénergies (%)  99796 non-null  float64
#  30  Column 68            0 non-null      float64
#  31  mois                 99840 non-null  int64
#  32  jour_semaine         99840 non-null  object
#  33  heure                99840 non-null  int64
#  34  saison               99840 non-null  object
#  35  variation            99745 non-null  float64
# dtypes: datetime64[ns](1), float64(25), int64(3), object(7)
# memory usage: 27.4+ MB

# %%
df_meteo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65932 entries, 0 to 65931
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   _id                     65932 non-null  object
#  1   Date - Heure            65932 non-null  datetime64[ns]
#  2   temperature_moyenne     59064 non-null  float64
#  3   pression_moyenne        59035 non-null  float64
#  4   humidite_moyenne        59062 non-null  float64
#  5   visibilité_moyenne      18533 non-null  float64
#  6   vent_moyen              59037 non-null  float64
#  7   vent_rafales_moyen      18537 non-null  float64
#  8   vent_rafales_max        18537 non-null  float64
#  9   vent_direction_moyenne  58854 non-null  float64
#  10  pluie_moyenne           18544 non-null  float64
#  11  pluie_intesite          51601 non-null  float64
#  12  uv                      32863 non-null  float64
#  13  uv_index                32863 non-null  float64
# dtypes: datetime64[ns](1), float64(12), object(1)
# memory usage: 7.0+ MB

# %%
df_final = pd.merge(left=df_conso, right=df_meteo, on = "Date - Heure")

# %%
df_final.head(5)
# Out:
#                       _id_x  ﻿Code INSEE région    Région              Nature  \
# 0  671a489fdc0de4ebb38f7e6a                  53  Bretagne  Données temps réel
# 1  672fd0160fe28f4022e5db1f                  53  Bretagne  Données temps réel
# 2  672fd2cc0fe28f4022e65986                  53  Bretagne  Données temps réel
# 3  671a4a1cdc0de4ebb38f952a                  53  Bretagne  Données temps réel
# 4  672fd2cc0fe28f4022e65987                  53  Bretagne  Données temps réel
#
#                   Date            Heure        Date - Heure  \
# 0  2023-06-01 00:00:00  0 days 21:15:00 2023-06-01 21:15:00
# 1  2023-06-01 00:00:00  0 days 21:15:00 2023-06-01 21:15:00
# 2  2023-06-01 00:00:00  0 days 00:15:00 2023-06-01 00:15:00
# 3  2023-06-01 00:00:00  0 days 00:15:00 2023-06-01 00:15:00
# 4  2023-06-01 00:00:00  0 days 00:45:00 2023-06-01 00:45:00
#
#    Consommation (MW)  Thermique (MW)  Nucléaire (MW)  ...  humidite_moyenne  \
# 0             2153.0           422.0             0.0  ...              89.5
# 1             2153.0           422.0             0.0  ...              89.5
# 2             2420.0           444.0             0.0  ...              89.5
# 3             2420.0           444.0             0.0  ...              89.5
# 4             2176.0           425.0             0.0  ...              90.4
#
#    visibilité_moyenne  vent_moyen  vent_rafales_moyen  vent_rafales_max  \
# 0                 NaN        6.60                 NaN               NaN
# 1                 NaN        6.60                 NaN               NaN
# 2             11500.0       12.35                32.4              39.6
# 3             11500.0       12.35                32.4              39.6
# 4             11500.0       10.82                32.4              39.6
#
#    vent_direction_moyenne  pluie_moyenne  pluie_intesite   uv  uv_index
# 0                   46.50            NaN             0.0  0.0       0.0
# 1                   46.50            NaN             0.0  0.0       0.0
# 2                  122.75            0.0             0.0  0.0       0.0
# 3                  122.75            0.0             0.0  0.0       0.0
# 4                  110.80            0.0             0.0  0.0       0.0
#
# [5 rows x 49 columns]

# %%
df_final =df_final.drop(columns=['Nature', 
                                 'Heure',
                                 'Column 68', 
                                 '_id_x', 
                                 '_id_y', 
                                 'Région', 
                                 'Stockage batterie', 
                                 'Déstockage batterie',
                                'variation'])

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99840 entries, 0 to 99839
# Data columns (total 40 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ﻿Code INSEE région      99840 non-null  int64
#  1   Date                    99840 non-null  object
#  2   Date - Heure            99840 non-null  datetime64[ns]
#  3   Consommation (MW)       99796 non-null  float64
#  4   Thermique (MW)          99796 non-null  float64
#  5   Nucléaire (MW)          99796 non-null  float64
#  6   Eolien (MW)             99796 non-null  float64
#  7   Solaire (MW)            99796 non-null  float64
#  8   Hydraulique (MW)        99796 non-null  float64
#  9   Pompage (MW)            99796 non-null  float64
#  10  Bioénergies (MW)        99796 non-null  float64
#  11  Ech. physiques (MW)     99796 non-null  float64
#  12  TCO Thermique (%)       99674 non-null  float64
#  13  TCH Thermique (%)       99796 non-null  float64
#  14  TCO Nucléaire (%)       99674 non-null  float64
#  15  TCH Nucléaire (%)       0 non-null      float64
#  16  TCO Eolien (%)          99674 non-null  float64
#  17  TCH Eolien (%)          99796 non-null  float64
#  18  TCO Solaire (%)         99674 non-null  float64
#  19  TCH Solaire (%)         99796 non-null  float64
#  20  TCO Hydraulique (%)     99674 non-null  float64
#  21  TCH Hydraulique (%)     99796 non-null  float64
#  22  TCO Bioénergies (%)     99674 non-null  float64
#  23  TCH Bioénergies (%)     99796 non-null  float64
#  24  mois                    99840 non-null  int64
#  25  jour_semaine            99840 non-null  object
#  26  heure                   99840 non-null  int64
#  27  saison                  99840 non-null  object
#  28  temperature_moyenne     93132 non-null  float64
#  29  pression_moyenne        93130 non-null  float64
#  30  humidite_moyenne        93130 non-null  float64
#  31  visibilité_moyenne      28096 non-null  float64
#  32  vent_moyen              93132 non-null  float64
#  33  vent_rafales_moyen      28110 non-null  float64
#  34  vent_rafales_max        28110 non-null  float64
#  35  vent_direction_moyenne  92918 non-null  float64
#  36  pluie_moyenne           28118 non-null  float64
#  37  pluie_intesite          85818 non-null  float64
#  38  uv                      49824 non-null  float64
#  39  uv_index                49824 non-null  float64
# dtypes: datetime64[ns](1), float64(33), int64(3), object(3)
# memory usage: 31.2+ MB

# %%
del df_final[df_final.columns[0]]

# %%
df_final = df_final[df_final['Consommation (MW)'].notna()]

# %%
df_final.to_csv(end_file)

# %%
numeric_columns = [
    'Consommation (MW)', 'Thermique (MW)', 'Eolien (MW)', 
    'Solaire (MW)', 'Hydraulique (MW)', 'Pompage (MW)', 'Bioénergies (MW)', 
    'Ech. physiques (MW)', 
    'TCO Thermique (%)', 'TCH Thermique (%)',
    'TCO Eolien (%)', 'TCH Eolien (%)', 'TCO Solaire (%)', 'TCH Solaire (%)', 
    'TCO Hydraulique (%)', 'TCH Hydraulique (%)', 'TCO Bioénergies (%)', 'TCH Bioénergies (%)', 
    'temperature_moyenne', 'humidite_moyenne',"visibilité_moyenne", 'vent_moyen', 'vent_rafales_moyen',
    'vent_rafales_max', 'vent_direction_moyenne', 'pluie_moyenne', 'pluie_intesite', 'uv', 'uv_index'
]

# %%
numeric_columns_simpl = [
    'Consommation (MW)', 'Thermique (MW)', 'Eolien (MW)', 
    'Solaire (MW)', 'Hydraulique (MW)', 'Pompage (MW)', 'Bioénergies (MW)', 
    'Ech. physiques (MW)', 
    'temperature_moyenne', 'humidite_moyenne',"visibilité_moyenne", 'vent_moyen', 'vent_rafales_moyen',
    'vent_rafales_max', 'vent_direction_moyenne', 'pluie_moyenne', 'pluie_intensite', 'uv', 'uv_index'
]

# %%
# Visualisation des corrélations entre les différentes variables 
plt.figure(figsize=(10, 6))
# Sélectionner uniquement les colonnes numériques pour la corrélation
df_etude = df_final[numeric_columns_simpl]

# Calculer la matrice de corrélation
correlation_matrix = df_etude.corr()  # Calculer la matrice de corrélation
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Matrice de corrélation')
plt.show()
